# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader('data.txt',encoding="utf-8")
loader
# Out:
# /tmp/ipykernel_897/1866928829.py:1: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import TextLoader

# %%
text_documents = loader.load()
text_documents
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1140/2026846786.py in <cell line: 0>()
# ----> 1 text_documents = loader.load()
#       2 text_documents
#
# NameError: name 'loader' is not defined

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
textSplitter = RecursiveCharacterTextSplitter(chunk_size=200,chunk_overlap=20)

finalDocument = textSplitter.split_documents(text_documents)
finalDocument
# Out:
# [Document(metadata={'source': 'data.txt'}, page_content='AIR CLEANING WINDOW PANEL\nCOMPLETE PROJECT INFORMATION – CONSOLIDATED TEXT FILE\n\nPROJECT OVERVIEW\nProject title: Air Cleaning Window Panel'),
#  Document(metadata={'source': 'data.txt'}, page_content='The Air Cleaning Window Panel is a compact air-purification system designed to fit into a conventional window frame. The project combines window ventilation with multi-stage air filtration so'),
#  Document(metadata={'source': 'data.txt'}, page_content='air filtration so incoming air can be treated before entering an indoor space.'),
#  Document(metadata={'source': 'data.txt'}, page_content='The project involves indoor air quality, ventilation, particulate filtration, adsorption, electrostatic separation, sensors, electronics, mechanical integration, safety and prototype testing.'),
#  Document(metadata={'source': 'data.txt'}, page_content='1. PROJECT PURPOSE'),
#  Document(metadata={'source': 'data.txt'}, page_content='The primary purpose is to develop a compact, window-integrated air-cleaning device capable of reducing suspended particulate matter and assisting with control of odors and selected gaseous pollutants'),
#  Document(metadata={'source': 'data.txt'}, page_content='gaseous pollutants in incoming air.'),
#  Document(metadata={'source': 'data.txt'}, page_content='The concept is intended to:\n- Occupy the space of a window panel rather than floor/table space.\n- Provide controlled airflow through filtration stages.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Reduce larger suspended particles such as PM10.\n- Target finer particles such as PM2.5 using an electrostatic stage.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Use activated carbon/carbon-based filtration for odors and selected gaseous pollutants.\n- Monitor air-quality and system parameters using sensors.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Maintain safe operation of the electrostatic system.\n- Remain compact, affordable and reasonably energy-efficient.'),
#  Document(metadata={'source': 'data.txt'}, page_content='2. PROBLEM STATEMENT'),
#  Document(metadata={'source': 'data.txt'}, page_content='Conventional windows provide ventilation but do not actively remove airborne particulate matter and gaseous contaminants from outdoor air. Standalone air purifiers can improve indoor air quality but'),
#  Document(metadata={'source': 'data.txt'}, page_content='air quality but require additional floor/table space and do not directly integrate with the building ventilation opening.'),
#  Document(metadata={'source': 'data.txt'}, page_content='The project therefore investigates a hybrid approach in which a window panel performs both ventilation and air-cleaning functions.'),
#  Document(metadata={'source': 'data.txt'}, page_content='3. OBJECTIVES\n4. Develop a compact air-cleaning device that fits within a regular window frame.\n5. Reduce suspended particulate matter, particularly PM10 and PM2.5, from incoming air.'),
#  Document(metadata={'source': 'data.txt'}, page_content='6. Use activated carbon/carbon-based filtration to assist in controlling odors and gaseous pollutants.'),
#  Document(metadata={'source': 'data.txt'}, page_content='7. Integrate forced ventilation, sensing and filtration into one affordable and energy-conscious unit.'),
#  Document(metadata={'source': 'data.txt'}, page_content='8. Ensure safe operation of the electrostatic stage through insulation, grounding and controlled electrical design.'),
#  Document(metadata={'source': 'data.txt'}, page_content='9. Evaluate airflow, pressure drop, air-quality response and overall prototype performance.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Short version:\n- Develop a compact window-integrated air purifier.\n- Remove particulate and gaseous pollutants using multi-stage filtration.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Monitor and optimize air quality, airflow and safe operation.'),
#  Document(metadata={'source': 'data.txt'}, page_content='4. BASIC SYSTEM CONCEPT\nOverall airflow:\nOutdoor air -> Preliminary fabric filter -> Electrostatic filtration stage -> Activated carbon/final filter -> Fan-assisted clean air -> Indoor space.'),
#  Document(metadata={'source': 'data.txt'}, page_content='The system uses forced airflow from a fan to move air through the filtration stages.\n\n5. FILTRATION SYSTEM'),
#  Document(metadata={'source': 'data.txt'}, page_content='5.1 PRELIMINARY FABRIC FILTER\nA cotton/fabric filter was selected as the preliminary stage.\nPurpose:\n- Capture larger suspended particles.\n- Reduce particulate load reaching finer filtration stages.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Provide a simple and affordable first filtration barrier.'),
#  Document(metadata={'source': 'data.txt'}, page_content='The literature discussion also considered fabric filter cake formation. As dust accumulates, the deposited layer can affect particle capture and pressure drop.'),
#  Document(metadata={'source': 'data.txt'}, page_content='5.2 ELECTROSTATIC FILTRATION\nThe electrostatic stage was proposed to target fine particulate matter, particularly PM2.5.'),
#  Document(metadata={'source': 'data.txt'}, page_content='The concept involved a pair of electrically biased meshes/electrodes. Different configurations were discussed during development.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Design discussions included:\n- Positive and negative electrostatic meshes/electrodes.\n- Nichrome as a possible conductive/electrode-related material.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Rubber bush as a possible insulating/mechanical separation element.\n- A separate insulating spacer was considered and later removed from the proposed arrangement.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Electrical insulation and grounding remained essential safety requirements.\n- A step-up transformer/high-voltage supply was discussed for generating the required electrostatic field.'),
#  Document(metadata={'source': 'data.txt'}, page_content='The final electrostatic arrangement must be validated experimentally and electrically before being used in a finished prototype.'),
#  Document(metadata={'source': 'data.txt'}, page_content='5.3 ACTIVATED CARBON / FINAL FILTER\nActivated carbon was included because of its adsorption capability.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Potential functions:\n- Odor reduction.\n- Adsorption of selected gaseous contaminants/VOCs.\n- Additional polishing after particulate filtration.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Carbon fiber was also discussed as part of the final filtration layer.'),
#  Document(metadata={'source': 'data.txt'}, page_content='The final layer was conceptualized as a fabric/carbon-containing filter providing additional particle filtration and adsorption.'),
#  Document(metadata={'source': 'data.txt'}, page_content='6. FINAL THREE-STAGE FILTRATION CONCEPT\nLayer 1: Preliminary cotton/fabric filter for larger particles and PM10.\nLayer 2: Electrostatic mesh/electrode stage intended for fine-particle/PM2.5 capture.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Layer 3: Final fabric filter containing activated carbon/carbon fiber for residual particles, odors and selected gaseous pollutants.'),
#  Document(metadata={'source': 'data.txt'}, page_content='7. AIRFLOW SYSTEM\nAn external fan was included to drive air through the filtration system.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Reasons for forced airflow:\n- Controlled movement through filters.\n- Reduced dependence on natural pressure differences.\n- More predictable purification.\n- Active ventilation and purification.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Important considerations:\n- Airflow rate.\n- Fan power consumption.\n- Filter pressure drop.\n- Increasing resistance as filters load with dust.\n- Noise.\n- Overall clean-air delivery.'),
#  Document(metadata={'source': 'data.txt'}, page_content='8. PRESSURE DROP\nPressure drop was identified as an important performance parameter.'),
#  Document(metadata={'source': 'data.txt'}, page_content='As particulate matter accumulates:\n- Filter resistance may increase.\n- Airflow may decrease.\n- Fan power demand may increase.\n- Overall system performance may change.'),
#  Document(metadata={'source': 'data.txt'}, page_content='A pressure transducer/transmitter was considered for monitoring pressure conditions across the filtration assembly.\n\n9. SENSORS AND ELECTRONICS'),
#  Document(metadata={'source': 'data.txt'}, page_content='9.1 MQ135 AIR-QUALITY SENSOR\nThe MQ135 air-quality sensing module was selected/discussed for monitoring changes in air quality and gaseous pollutants.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Important limitation: MQ135 is a broad, indicative gas sensor. It should not automatically be treated as a laboratory-grade quantitative analyzer for specific pollutants without suitable calibration'),
#  Document(metadata={'source': 'data.txt'}, page_content='calibration and controlled testing.'),
#  Document(metadata={'source': 'data.txt'}, page_content='9.2 BLUE PILL MICROCONTROLLER\nThe Blue Pill microcontroller was proposed as the central controller for sensor acquisition, monitoring, pressure/current monitoring and possible fan-control functions.'),
#  Document(metadata={'source': 'data.txt'}, page_content='9.3 CURRENT TRANSDUCER\nA current transducer was discussed for monitoring electrical current associated with the electrostatic subsystem, supporting electrical monitoring and safety checks.'),
#  Document(metadata={'source': 'data.txt'}, page_content='9.4 PRESSURE TRANSDUCER / TRANSMITTER\nA pressure transducer/transmitter was proposed to measure pressure conditions in the filtration system, supporting pressure-drop and filter-loading studies.'),
#  Document(metadata={'source': 'data.txt'}, page_content='10. POWER SUPPLY\nThe system requires suitable power supplies for the fan, sensors, microcontroller and electrostatic/high-voltage subsystem.'),
#  Document(metadata={'source': 'data.txt'}, page_content='A step-up transformer/high-voltage supply was discussed for the electrostatic system.'),
#  Document(metadata={'source': 'data.txt'}, page_content='11. ELECTROSTATIC SAFETY\nPotential hazards:\n- Electric shock.\n- Accidental contact with energized components.\n- Electrical arcing/sparking.\n- Improper insulation.\n- Inadequate electrical clearances.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- High-voltage leakage.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Safety measures discussed:\n- Proper insulation.\n- Grounding.\n- Enclosure of energized components.\n- Controlled high-voltage generation.\n- Current limiting.\n- Safe wiring.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Safe wiring.\n- Adequate electrical clearances.\n- Preventing user access to energized parts.\n- Suitable insulating materials.'),
#  Document(metadata={'source': 'data.txt'}, page_content='12. MECHANICAL FRAME\nThe system was intended to fit within a regular window frame.\n\nMaterials discussed:\n- Wooden frame.\n- Aluminium structural elements.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Mechanical requirements:\n- Structural rigidity.\n- Correct fit within the window opening.\n- Space for filters, fan, sensors and wiring.\n- Safe enclosure of the electrostatic system.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Easy cleaning and filter replacement.\n- Proper sealing.\n- Practical installation and maintenance.'),
#  Document(metadata={'source': 'data.txt'}, page_content='An exploded engineering drawing with major frame dimensions was identified as a useful design output. Exact final dimensions were not fixed and should be determined from the target window and'),
#  Document(metadata={'source': 'data.txt'}, page_content='target window and prototype.'),
#  Document(metadata={'source': 'data.txt'}, page_content='13. MAIN MATERIALS AND COMPONENTS\nFrame: wood; aluminium structural elements.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Filtration: cotton fabric filter; electrostatic meshes/electrodes; Nichrome/conductive material concept; activated carbon; carbon fiber; final fabric filter.\nAir movement: external fan.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Sensors: MQ135; pressure transducer/transmitter; current transducer.\nControl: Blue Pill microcontroller.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Electrical: power supply; step-up transformer/high-voltage supply; insulating components; wiring and grounding.\nIsolation: rubber bush concept; insulation.'),
#  Document(metadata={'source': 'data.txt'}, page_content='14. LITERATURE REVIEW TOPICS'),
#  Document(metadata={'source': 'data.txt'}, page_content='14.1 PM2.5 AND INDOOR PARTICULATE MATTER'),
#  Document(metadata={'source': 'data.txt'}, page_content='Research on PM2.5 and indoor particulate matter was considered important because fine particles can penetrate indoor environments and are difficult to remove using simple natural ventilation.'),
#  Document(metadata={'source': 'data.txt'}, page_content='14.2 VOC ADSORPTION USING ACTIVATED CARBON'),
#  Document(metadata={'source': 'data.txt'}, page_content='Topics included VOC adsorption, odor removal, gas-phase pollutant control, adsorption capacity, pollutant concentration, contact conditions and carbon saturation.'),
#  Document(metadata={'source': 'data.txt'}, page_content='14.3 FABRIC FILTRATION\nTopics included particle capture, filter cake formation, pressure drop, filtration efficiency and filter loading.'),
#  Document(metadata={'source': 'data.txt'}, page_content='14.4 HEPA FILTRATION'),
#  Document(metadata={'source': 'data.txt'}, page_content='HEPA filtration was considered as a benchmark for high-efficiency particulate removal. High filtration efficiency can be associated with increased pressure drop. The project does not automatically'),
#  Document(metadata={'source': 'data.txt'}, page_content='not automatically claim HEPA-level performance.'),
#  Document(metadata={'source': 'data.txt'}, page_content='14.5 MXENE NANOSHEETS'),
#  Document(metadata={'source': 'data.txt'}, page_content='MXene nanosheets were discussed as an advanced filtration-material research topic involving high surface area and potential functional filtration media. This was part of the literature review rather'),
#  Document(metadata={'source': 'data.txt'}, page_content='review rather than necessarily a selected prototype material.'),
#  Document(metadata={'source': 'data.txt'}, page_content='14.6 HYBRID ELECTROSTATIC FILTRATION\nHybrid electrostatic systems, including the HYBRYDA+ concept, were discussed as examples of combining mechanical filtration and electrostatic particle capture.'),
#  Document(metadata={'source': 'data.txt'}, page_content='14.7 NATURAL VENTILATION\nTopics included outdoor-to-indoor air movement, window ventilation, air-quality limitations and the opportunity to treat incoming ventilation air.'),
#  Document(metadata={'source': 'data.txt'}, page_content='14.8 TRICKLE VENTS\nTrickle vents were considered as examples of compact ventilation openings integrated into building envelopes, relevant to controlled ventilation and window-integrated filtration.'),
#  Document(metadata={'source': 'data.txt'}, page_content='14.9 AIRFLOW AND PRESSURE DROP\nThe project needs to balance filtration efficiency, pressure drop, fan power and clean-air delivery.'),
#  Document(metadata={'source': 'data.txt'}, page_content='15. RESEARCH METHODOLOGY\n16. Identify the indoor-air-quality and ventilation problem.\n17. Review particulate and gaseous pollutant removal technologies.'),
#  Document(metadata={'source': 'data.txt'}, page_content='18. Study fabric filtration, electrostatic filtration and activated-carbon adsorption.\n19. Select materials and components.\n20. Develop the window-panel mechanical design.'),
#  Document(metadata={'source': 'data.txt'}, page_content='21. Develop the airflow path.\n22. Integrate filtration layers.\n23. Integrate fan and sensors.\n24. Develop Blue Pill-based monitoring/control.'),
#  Document(metadata={'source': 'data.txt'}, page_content='25. Develop the electrostatic system with insulation, grounding and safety.\n26. Fabricate the prototype.\n27. Conduct controlled performance testing.'),
#  Document(metadata={'source': 'data.txt'}, page_content='28. Compare air quality before and after filtration.\n29. Evaluate airflow, pressure drop, energy use and electrical behavior.\n30. Identify limitations and optimize the design.'),
#  Document(metadata={'source': 'data.txt'}, page_content='16. CONSTRUCTION PHASE\nThe construction concept involved:\n1. Fabricating a rigid window-compatible frame.\n2. Preparing filtration layers.\n3. Mounting the preliminary fabric filter.'),
#  Document(metadata={'source': 'data.txt'}, page_content='4. Installing the electrostatic stage.\n5. Installing the activated-carbon/final filter.\n6. Providing the fan and airflow path.\n7. Installing sensors.\n8. Installing the Blue Pill controller.'),
#  Document(metadata={'source': 'data.txt'}, page_content='9. Installing pressure and current monitoring.\n10. Providing suitable power supplies.\n11. Enclosing and insulating the electrostatic subsystem.\n12. Testing airflow and electrical operation.'),
#  Document(metadata={'source': 'data.txt'}, page_content='13. Providing access for filter maintenance and replacement.'),
#  Document(metadata={'source': 'data.txt'}, page_content='17. TESTING PARAMETERS\nAir quality:\n- PM10 before and after filtration.\n- PM2.5 before and after filtration.\n- Indicative MQ135 response.\n- Odor/gaseous pollutant response where measurable.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Airflow:\n- Airflow rate.\n- Fan performance.\n- Clean-air delivery.\n\nPressure:\n- Pressure drop across filters.\n- Pressure change with filter loading.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Electrical:\n- Electrostatic current.\n- Voltage behavior where safely measurable.\n- Fan electrical consumption.\n- Overall energy consumption.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Operational:\n- Noise.\n- Filter loading.\n- Maintenance requirements.\n- Stability of operation.'),
#  Document(metadata={'source': 'data.txt'}, page_content='18. PERFORMANCE EVALUATION\nA useful experimental comparison is:\nBefore filtration: measure incoming/outdoor air.\nDuring filtration: operate the panel at a defined fan setting.'),
#  Document(metadata={'source': 'data.txt'}, page_content='After filtration: measure treated air.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Compare PM2.5 reduction, PM10 reduction, sensor response, pressure drop, airflow and power consumption.\n\nRemoval efficiency:\nRemoval efficiency (%) = [(C_in - C_out) / C_in] x 100'),
#  Document(metadata={'source': 'data.txt'}, page_content='C_in = concentration before filtration.\nC_out = concentration after filtration.\n\nUse this only when the measurement setup and sensor accuracy are appropriate.'),
#  Document(metadata={'source': 'data.txt'}, page_content='19. EXPECTED PROJECT CONTRIBUTIONS\nThe project combines:\n- Building ventilation.\n- Indoor environmental quality.\n- Mechanical filtration.\n- Electrostatic particle separation.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Activated-carbon adsorption.\n- Air-quality sensing.\n- Microcontroller-based monitoring.\n- Pressure monitoring.\n- Electrical monitoring.\n- Compact window integration.'),
#  Document(metadata={'source': 'data.txt'}, page_content='The main contribution is exploration of a window-mounted air-cleaning system that treats incoming ventilation air while occupying a compact panel rather than requiring a separate standalone purifier.'),
#  Document(metadata={'source': 'data.txt'}, page_content='20. STRENGTHS\n- Compact and space-efficient.\n- Directly integrated into a window.\n- Multi-stage filtration.\n- Targets different pollutant categories.\n- Potential real-time monitoring.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Replaceable filtration components.\n- Potentially affordable.\n- Energy-conscious design potential.\n- Combines civil/building engineering with electronics and environmental engineering.'),
#  Document(metadata={'source': 'data.txt'}, page_content='21. LIMITATIONS\n- Electrostatic filtration introduces high-voltage safety requirements.\n- Filter pressure drop can reduce airflow.\n- Higher fan power may be required as resistance increases.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- MQ135 is not a highly specific quantitative pollutant analyzer without calibration.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Activated carbon performance depends on carbon properties, pollutant concentration, contact time and saturation.\n- Compact window panels have limited filter area.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Window integration requires proper sealing and structural support.\n- Outdoor weather exposure may affect materials.\n- Maintenance and filter replacement must be considered.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Prototype measurements require controlled testing.\n- Quantitative performance claims should be based on validated measurements.'),
#  Document(metadata={'source': 'data.txt'}, page_content='22. DESIGN CHALLENGES\n23. Achieving sufficient filtration without excessive pressure drop.\n24. Generating effective electrostatic particle capture safely.'),
#  Document(metadata={'source': 'data.txt'}, page_content='25. Preventing electrical shock and sparking.\n26. Keeping the panel compact.\n27. Maintaining sufficient airflow.\n28. Managing fan power consumption.\n29. Providing adequate sensor accuracy.'),
#  Document(metadata={'source': 'data.txt'}, page_content='30. Making filters easy to replace.\n31. Maintaining structural stability.\n32. Integrating electronics without obstructing airflow.\n33. Controlling noise.'),
#  Document(metadata={'source': 'data.txt'}, page_content='34. Protecting the system from environmental exposure.'),
#  Document(metadata={'source': 'data.txt'}, page_content='23. DESIGN DECISIONS RECORDED\n- Window-integrated air-cleaning panel rather than conventional standalone purifier.\n- Three-stage filtration became the main arrangement.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Cotton/fabric filtration for preliminary stage.\n- Electrostatic filtration for fine-particle stage.\n- Activated carbon/carbon fiber for final stage.\n- External fan for forced airflow.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- MQ135 for air-quality monitoring.\n- Blue Pill as microcontroller.\n- Pressure sensing and current sensing included.\n- High-voltage step-up system considered.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Rubber-bush insulation/separation concept considered.\n- Separate insulating spacer later removed from proposed design.\n- Electrical insulation and grounding retained as mandatory.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Wooden/aluminium frame concept.\n- Exploded engineering drawing with dimensions identified as a design output.'),
#  Document(metadata={'source': 'data.txt'}, page_content='24. RESEARCH THRUST AREAS\n- Window-integrated air purification.\n- Hybrid mechanical-electrostatic filtration.\n- PM2.5 removal through compact electrostatic systems.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Activated-carbon adsorption in ventilation systems.\n- Indoor air-quality improvement through filtered ventilation.\n- Pressure-drop optimization in compact filters.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Energy-efficient air-cleaning ventilation.\n- Sensor-based monitoring of window-integrated purification.\n- Building-envelope-integrated air filtration.'),
#  Document(metadata={'source': 'data.txt'}, page_content='25. FUTURE DEVELOPMENT\n- Optimize filter area.\n- Reduce pressure drop.\n- Improve PM2.5 measurement accuracy.\n- Replace/supplement MQ135 with a dedicated particulate sensor.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Improve electrostatic-field uniformity.\n- Improve high-voltage safety.\n- Reduce fan power consumption.\n- Reduce noise.\n- Develop replaceable filter cartridges.\n- Add automatic fan-speed control.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Add filter-life monitoring.\n- Improve weather resistance.\n- Improve window sealing.\n- Develop a more compact enclosure.\n- Conduct long-duration field testing.'),
#  Document(metadata={'source': 'data.txt'}, page_content='26. FINAL SYSTEM ARCHITECTURE\nWindow opening\n  -> Preliminary fabric filter\n  -> Electrostatic fine-particle stage\n  -> Activated carbon/final filter\n  -> Fan/forced airflow'),
#  Document(metadata={'source': 'data.txt'}, page_content='-> Cleaner air to indoor space'),
#  Document(metadata={'source': 'data.txt'}, page_content='Monitoring and control:\nMQ135 + pressure transducer + current transducer\n  -> Blue Pill microcontroller\n  -> monitoring/control functions'),
#  Document(metadata={'source': 'data.txt'}, page_content='27. THESIS/REPORT SECTIONS DISCUSSED\n- Abstract.\n- Introduction.\n- Problem statement.\n- Objectives.\n- Thesis contributions.\n- Literature review.\n- Research methodology.\n- Materials used.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Materials used.\n- Sensors and electronics.\n- Construction phase.\n- Discussion.\n- Summary/conclusion.\n- References.'),
#  Document(metadata={'source': 'data.txt'}, page_content='28. MATERIALS SECTION DISCUSSED\n- Wooden frame.\n- Aluminium structural elements.\n- Cotton fabric filter.\n- Electrostatic mesh/electrode materials.\n- Activated carbon.\n- Carbon fiber.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Carbon fiber.\n- Rubber insulating components.\n- Fan.\n- Sensors.\n- Microcontroller.\n- Power supply.\n- High-voltage components.\n- Wiring and grounding components.'),
#  Document(metadata={'source': 'data.txt'}, page_content='29. IMPORTANT ENGINEERING NOTE'),
#  Document(metadata={'source': 'data.txt'}, page_content='The project description represents concepts discussed during project development. It does not establish that every component, dimension or performance value has been experimentally validated.'),
#  Document(metadata={'source': 'data.txt'}, page_content='For the final thesis, clearly distinguish between:\n- Proposed design.\n- Fabricated prototype.\n- Experimental observations.\n- Measured results.\n- Literature-supported findings.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Future recommendations.'),
#  Document(metadata={'source': 'data.txt'}, page_content='30. OVERALL CONCLUSION\nThe Air Cleaning Window Panel is a compact building-integrated air-cleaning concept combining ventilation and filtration in a single window-mounted system.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Its core design uses:\n- Preliminary fabric filtration for larger particles.\n- Electrostatic filtration for fine particulate matter.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Activated-carbon/carbon-based final filtration for odors and selected gaseous pollutants.\n- A fan for forced airflow.\n- MQ135, pressure and current sensing.\n- Blue Pill microcontroller.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Wooden/aluminium frame.\n- A dedicated safety approach for the electrostatic subsystem.'),
#  Document(metadata={'source': 'data.txt'}, page_content='The project has potential as a practical civil/environmental engineering prototype because it addresses indoor air quality while integrating directly with a building opening. The most important areas'),
#  Document(metadata={'source': 'data.txt'}, page_content='important areas requiring rigorous validation are particulate-removal efficiency, airflow, pressure drop, energy consumption, electrostatic safety, sensor accuracy and long-term filter performance.'),
#  Document(metadata={'source': 'data.txt'}, page_content='END OF CONSOLIDATED PROJECT INFORMATION')]

# %%
texts = [doc.page_content for doc in finalDocument]

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-l6-v2")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
print(embeddings)
# Out:
# model_name='sentence-transformers/all-MiniLM-l6-v2' cache_folder=None model_kwargs={} encode_kwargs={} query_encode_kwargs={} multi_process=False show_progress=False

# %%
# vector Store in DB
from langchain_community.vectorstores import FAISS
db = FAISS.from_documents(finalDocuments, embeddings)
db
# Out:
# /tmp/ipykernel_1140/2745234565.py:2: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.vectorstores import FAISS
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_1140/2745234565.py in <cell line: 0>()
#       1 # vector Store in DB
#       2 from langchain_community.vectorstores import FAISS
# ----> 3 db = FAISS.from_documents(finalDocuments, embeddings)
#       4 db
#
# NameError: name 'finalDocuments' is not defined

# %%
from langchain_community.document_loaders import TextLoader
loader = TextLoader('data.txt',encoding="utf-8")
loader

# %%
text_documents = loader.load()
text_documents
# Out:
# [Document(metadata={'source': 'data.txt'}, page_content='AIR CLEANING WINDOW PANEL\nCOMPLETE PROJECT INFORMATION – CONSOLIDATED TEXT FILE\n\nPROJECT OVERVIEW\nProject title: Air Cleaning Window Panel\n\nThe Air Cleaning Window Panel is a compact air-purification system designed to fit into a conventional window frame. The project combines window ventilation with multi-stage air filtration so incoming air can be treated before entering an indoor space.\n\nThe project involves indoor air quality, ventilation, particulate filtration, adsorption, electrostatic separation, sensors, electronics, mechanical integration, safety and prototype testing.\n\n1. PROJECT PURPOSE\nThe primary purpose is to develop a compact, window-integrated air-cleaning device capable of reducing suspended particulate matter and assisting with control of odors and selected gaseous pollutants in incoming air.\n\nThe concept is intended to:\n- Occupy the space of a window panel rather than floor/table space.\n- Provide controlled airflow through filtration stages.\n- Reduce larger suspended particles such as PM10.\n- Target finer particles such as PM2.5 using an electrostatic stage.\n- Use activated carbon/carbon-based filtration for odors and selected gaseous pollutants.\n- Monitor air-quality and system parameters using sensors.\n- Maintain safe operation of the electrostatic system.\n- Remain compact, affordable and reasonably energy-efficient.\n\n2. PROBLEM STATEMENT\nConventional windows provide ventilation but do not actively remove airborne particulate matter and gaseous contaminants from outdoor air. Standalone air purifiers can improve indoor air quality but require additional floor/table space and do not directly integrate with the building ventilation opening.\n\nThe project therefore investigates a hybrid approach in which a window panel performs both ventilation and air-cleaning functions.\n\n3. OBJECTIVES\n4. Develop a compact air-cleaning device that fits within a regular window frame.\n5. Reduce suspended particulate matter, particularly PM10 and PM2.5, from incoming air.\n6. Use activated carbon/carbon-based filtration to assist in controlling odors and gaseous pollutants.\n7. Integrate forced ventilation, sensing and filtration into one affordable and energy-conscious unit.\n8. Ensure safe operation of the electrostatic stage through insulation, grounding and controlled electrical design.\n9. Evaluate airflow, pressure drop, air-quality response and overall prototype performance.\n\nShort version:\n- Develop a compact window-integrated air purifier.\n- Remove particulate and gaseous pollutants using multi-stage filtration.\n- Monitor and optimize air quality, airflow and safe operation.\n\n4. BASIC SYSTEM CONCEPT\nOverall airflow:\nOutdoor air -> Preliminary fabric filter -> Electrostatic filtration stage -> Activated carbon/final filter -> Fan-assisted clean air -> Indoor space.\n\nThe system uses forced airflow from a fan to move air through the filtration stages.\n\n5. FILTRATION SYSTEM\n\n5.1 PRELIMINARY FABRIC FILTER\nA cotton/fabric filter was selected as the preliminary stage.\nPurpose:\n- Capture larger suspended particles.\n- Reduce particulate load reaching finer filtration stages.\n- Provide a simple and affordable first filtration barrier.\n\nThe literature discussion also considered fabric filter cake formation. As dust accumulates, the deposited layer can affect particle capture and pressure drop.\n\n5.2 ELECTROSTATIC FILTRATION\nThe electrostatic stage was proposed to target fine particulate matter, particularly PM2.5.\n\nThe concept involved a pair of electrically biased meshes/electrodes. Different configurations were discussed during development.\n\nDesign discussions included:\n- Positive and negative electrostatic meshes/electrodes.\n- Nichrome as a possible conductive/electrode-related material.\n- Rubber bush as a possible insulating/mechanical separation element.\n- A separate insulating spacer was considered and later ...

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
textSplitter = RecursiveCharacterTextSplitter(chunk_size=200,chunk_overlap=20)

finalDocument = textSplitter.split_documents(text_documents)
finalDocument
# Out:
# [Document(metadata={'source': 'data.txt'}, page_content='AIR CLEANING WINDOW PANEL\nCOMPLETE PROJECT INFORMATION – CONSOLIDATED TEXT FILE\n\nPROJECT OVERVIEW\nProject title: Air Cleaning Window Panel'),
#  Document(metadata={'source': 'data.txt'}, page_content='The Air Cleaning Window Panel is a compact air-purification system designed to fit into a conventional window frame. The project combines window ventilation with multi-stage air filtration so'),
#  Document(metadata={'source': 'data.txt'}, page_content='air filtration so incoming air can be treated before entering an indoor space.'),
#  Document(metadata={'source': 'data.txt'}, page_content='The project involves indoor air quality, ventilation, particulate filtration, adsorption, electrostatic separation, sensors, electronics, mechanical integration, safety and prototype testing.'),
#  Document(metadata={'source': 'data.txt'}, page_content='1. PROJECT PURPOSE'),
#  Document(metadata={'source': 'data.txt'}, page_content='The primary purpose is to develop a compact, window-integrated air-cleaning device capable of reducing suspended particulate matter and assisting with control of odors and selected gaseous pollutants'),
#  Document(metadata={'source': 'data.txt'}, page_content='gaseous pollutants in incoming air.'),
#  Document(metadata={'source': 'data.txt'}, page_content='The concept is intended to:\n- Occupy the space of a window panel rather than floor/table space.\n- Provide controlled airflow through filtration stages.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Reduce larger suspended particles such as PM10.\n- Target finer particles such as PM2.5 using an electrostatic stage.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Use activated carbon/carbon-based filtration for odors and selected gaseous pollutants.\n- Monitor air-quality and system parameters using sensors.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Maintain safe operation of the electrostatic system.\n- Remain compact, affordable and reasonably energy-efficient.'),
#  Document(metadata={'source': 'data.txt'}, page_content='2. PROBLEM STATEMENT'),
#  Document(metadata={'source': 'data.txt'}, page_content='Conventional windows provide ventilation but do not actively remove airborne particulate matter and gaseous contaminants from outdoor air. Standalone air purifiers can improve indoor air quality but'),
#  Document(metadata={'source': 'data.txt'}, page_content='air quality but require additional floor/table space and do not directly integrate with the building ventilation opening.'),
#  Document(metadata={'source': 'data.txt'}, page_content='The project therefore investigates a hybrid approach in which a window panel performs both ventilation and air-cleaning functions.'),
#  Document(metadata={'source': 'data.txt'}, page_content='3. OBJECTIVES\n4. Develop a compact air-cleaning device that fits within a regular window frame.\n5. Reduce suspended particulate matter, particularly PM10 and PM2.5, from incoming air.'),
#  Document(metadata={'source': 'data.txt'}, page_content='6. Use activated carbon/carbon-based filtration to assist in controlling odors and gaseous pollutants.'),
#  Document(metadata={'source': 'data.txt'}, page_content='7. Integrate forced ventilation, sensing and filtration into one affordable and energy-conscious unit.'),
#  Document(metadata={'source': 'data.txt'}, page_content='8. Ensure safe operation of the electrostatic stage through insulation, grounding and controlled electrical design.'),
#  Document(metadata={'source': 'data.txt'}, page_content='9. Evaluate airflow, pressure drop, air-quality response and overall prototype performance.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Short version:\n- Develop a compact window-integrated air purifier.\n- Remove particulate and gaseous pollutants using multi-stage filtration.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Monitor and optimize air quality, airflow and safe operation.'),
#  Document(metadata={'source': 'data.txt'}, page_content='4. BASIC SYSTEM CONCEPT\nOverall airflow:\nOutdoor air -> Preliminary fabric filter -> Electrostatic filtration stage -> Activated carbon/final filter -> Fan-assisted clean air -> Indoor space.'),
#  Document(metadata={'source': 'data.txt'}, page_content='The system uses forced airflow from a fan to move air through the filtration stages.\n\n5. FILTRATION SYSTEM'),
#  Document(metadata={'source': 'data.txt'}, page_content='5.1 PRELIMINARY FABRIC FILTER\nA cotton/fabric filter was selected as the preliminary stage.\nPurpose:\n- Capture larger suspended particles.\n- Reduce particulate load reaching finer filtration stages.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Provide a simple and affordable first filtration barrier.'),
#  Document(metadata={'source': 'data.txt'}, page_content='The literature discussion also considered fabric filter cake formation. As dust accumulates, the deposited layer can affect particle capture and pressure drop.'),
#  Document(metadata={'source': 'data.txt'}, page_content='5.2 ELECTROSTATIC FILTRATION\nThe electrostatic stage was proposed to target fine particulate matter, particularly PM2.5.'),
#  Document(metadata={'source': 'data.txt'}, page_content='The concept involved a pair of electrically biased meshes/electrodes. Different configurations were discussed during development.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Design discussions included:\n- Positive and negative electrostatic meshes/electrodes.\n- Nichrome as a possible conductive/electrode-related material.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Rubber bush as a possible insulating/mechanical separation element.\n- A separate insulating spacer was considered and later removed from the proposed arrangement.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Electrical insulation and grounding remained essential safety requirements.\n- A step-up transformer/high-voltage supply was discussed for generating the required electrostatic field.'),
#  Document(metadata={'source': 'data.txt'}, page_content='The final electrostatic arrangement must be validated experimentally and electrically before being used in a finished prototype.'),
#  Document(metadata={'source': 'data.txt'}, page_content='5.3 ACTIVATED CARBON / FINAL FILTER\nActivated carbon was included because of its adsorption capability.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Potential functions:\n- Odor reduction.\n- Adsorption of selected gaseous contaminants/VOCs.\n- Additional polishing after particulate filtration.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Carbon fiber was also discussed as part of the final filtration layer.'),
#  Document(metadata={'source': 'data.txt'}, page_content='The final layer was conceptualized as a fabric/carbon-containing filter providing additional particle filtration and adsorption.'),
#  Document(metadata={'source': 'data.txt'}, page_content='6. FINAL THREE-STAGE FILTRATION CONCEPT\nLayer 1: Preliminary cotton/fabric filter for larger particles and PM10.\nLayer 2: Electrostatic mesh/electrode stage intended for fine-particle/PM2.5 capture.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Layer 3: Final fabric filter containing activated carbon/carbon fiber for residual particles, odors and selected gaseous pollutants.'),
#  Document(metadata={'source': 'data.txt'}, page_content='7. AIRFLOW SYSTEM\nAn external fan was included to drive air through the filtration system.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Reasons for forced airflow:\n- Controlled movement through filters.\n- Reduced dependence on natural pressure differences.\n- More predictable purification.\n- Active ventilation and purification.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Important considerations:\n- Airflow rate.\n- Fan power consumption.\n- Filter pressure drop.\n- Increasing resistance as filters load with dust.\n- Noise.\n- Overall clean-air delivery.'),
#  Document(metadata={'source': 'data.txt'}, page_content='8. PRESSURE DROP\nPressure drop was identified as an important performance parameter.'),
#  Document(metadata={'source': 'data.txt'}, page_content='As particulate matter accumulates:\n- Filter resistance may increase.\n- Airflow may decrease.\n- Fan power demand may increase.\n- Overall system performance may change.'),
#  Document(metadata={'source': 'data.txt'}, page_content='A pressure transducer/transmitter was considered for monitoring pressure conditions across the filtration assembly.\n\n9. SENSORS AND ELECTRONICS'),
#  Document(metadata={'source': 'data.txt'}, page_content='9.1 MQ135 AIR-QUALITY SENSOR\nThe MQ135 air-quality sensing module was selected/discussed for monitoring changes in air quality and gaseous pollutants.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Important limitation: MQ135 is a broad, indicative gas sensor. It should not automatically be treated as a laboratory-grade quantitative analyzer for specific pollutants without suitable calibration'),
#  Document(metadata={'source': 'data.txt'}, page_content='calibration and controlled testing.'),
#  Document(metadata={'source': 'data.txt'}, page_content='9.2 BLUE PILL MICROCONTROLLER\nThe Blue Pill microcontroller was proposed as the central controller for sensor acquisition, monitoring, pressure/current monitoring and possible fan-control functions.'),
#  Document(metadata={'source': 'data.txt'}, page_content='9.3 CURRENT TRANSDUCER\nA current transducer was discussed for monitoring electrical current associated with the electrostatic subsystem, supporting electrical monitoring and safety checks.'),
#  Document(metadata={'source': 'data.txt'}, page_content='9.4 PRESSURE TRANSDUCER / TRANSMITTER\nA pressure transducer/transmitter was proposed to measure pressure conditions in the filtration system, supporting pressure-drop and filter-loading studies.'),
#  Document(metadata={'source': 'data.txt'}, page_content='10. POWER SUPPLY\nThe system requires suitable power supplies for the fan, sensors, microcontroller and electrostatic/high-voltage subsystem.'),
#  Document(metadata={'source': 'data.txt'}, page_content='A step-up transformer/high-voltage supply was discussed for the electrostatic system.'),
#  Document(metadata={'source': 'data.txt'}, page_content='11. ELECTROSTATIC SAFETY\nPotential hazards:\n- Electric shock.\n- Accidental contact with energized components.\n- Electrical arcing/sparking.\n- Improper insulation.\n- Inadequate electrical clearances.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- High-voltage leakage.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Safety measures discussed:\n- Proper insulation.\n- Grounding.\n- Enclosure of energized components.\n- Controlled high-voltage generation.\n- Current limiting.\n- Safe wiring.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Safe wiring.\n- Adequate electrical clearances.\n- Preventing user access to energized parts.\n- Suitable insulating materials.'),
#  Document(metadata={'source': 'data.txt'}, page_content='12. MECHANICAL FRAME\nThe system was intended to fit within a regular window frame.\n\nMaterials discussed:\n- Wooden frame.\n- Aluminium structural elements.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Mechanical requirements:\n- Structural rigidity.\n- Correct fit within the window opening.\n- Space for filters, fan, sensors and wiring.\n- Safe enclosure of the electrostatic system.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Easy cleaning and filter replacement.\n- Proper sealing.\n- Practical installation and maintenance.'),
#  Document(metadata={'source': 'data.txt'}, page_content='An exploded engineering drawing with major frame dimensions was identified as a useful design output. Exact final dimensions were not fixed and should be determined from the target window and'),
#  Document(metadata={'source': 'data.txt'}, page_content='target window and prototype.'),
#  Document(metadata={'source': 'data.txt'}, page_content='13. MAIN MATERIALS AND COMPONENTS\nFrame: wood; aluminium structural elements.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Filtration: cotton fabric filter; electrostatic meshes/electrodes; Nichrome/conductive material concept; activated carbon; carbon fiber; final fabric filter.\nAir movement: external fan.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Sensors: MQ135; pressure transducer/transmitter; current transducer.\nControl: Blue Pill microcontroller.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Electrical: power supply; step-up transformer/high-voltage supply; insulating components; wiring and grounding.\nIsolation: rubber bush concept; insulation.'),
#  Document(metadata={'source': 'data.txt'}, page_content='14. LITERATURE REVIEW TOPICS'),
#  Document(metadata={'source': 'data.txt'}, page_content='14.1 PM2.5 AND INDOOR PARTICULATE MATTER'),
#  Document(metadata={'source': 'data.txt'}, page_content='Research on PM2.5 and indoor particulate matter was considered important because fine particles can penetrate indoor environments and are difficult to remove using simple natural ventilation.'),
#  Document(metadata={'source': 'data.txt'}, page_content='14.2 VOC ADSORPTION USING ACTIVATED CARBON'),
#  Document(metadata={'source': 'data.txt'}, page_content='Topics included VOC adsorption, odor removal, gas-phase pollutant control, adsorption capacity, pollutant concentration, contact conditions and carbon saturation.'),
#  Document(metadata={'source': 'data.txt'}, page_content='14.3 FABRIC FILTRATION\nTopics included particle capture, filter cake formation, pressure drop, filtration efficiency and filter loading.'),
#  Document(metadata={'source': 'data.txt'}, page_content='14.4 HEPA FILTRATION'),
#  Document(metadata={'source': 'data.txt'}, page_content='HEPA filtration was considered as a benchmark for high-efficiency particulate removal. High filtration efficiency can be associated with increased pressure drop. The project does not automatically'),
#  Document(metadata={'source': 'data.txt'}, page_content='not automatically claim HEPA-level performance.'),
#  Document(metadata={'source': 'data.txt'}, page_content='14.5 MXENE NANOSHEETS'),
#  Document(metadata={'source': 'data.txt'}, page_content='MXene nanosheets were discussed as an advanced filtration-material research topic involving high surface area and potential functional filtration media. This was part of the literature review rather'),
#  Document(metadata={'source': 'data.txt'}, page_content='review rather than necessarily a selected prototype material.'),
#  Document(metadata={'source': 'data.txt'}, page_content='14.6 HYBRID ELECTROSTATIC FILTRATION\nHybrid electrostatic systems, including the HYBRYDA+ concept, were discussed as examples of combining mechanical filtration and electrostatic particle capture.'),
#  Document(metadata={'source': 'data.txt'}, page_content='14.7 NATURAL VENTILATION\nTopics included outdoor-to-indoor air movement, window ventilation, air-quality limitations and the opportunity to treat incoming ventilation air.'),
#  Document(metadata={'source': 'data.txt'}, page_content='14.8 TRICKLE VENTS\nTrickle vents were considered as examples of compact ventilation openings integrated into building envelopes, relevant to controlled ventilation and window-integrated filtration.'),
#  Document(metadata={'source': 'data.txt'}, page_content='14.9 AIRFLOW AND PRESSURE DROP\nThe project needs to balance filtration efficiency, pressure drop, fan power and clean-air delivery.'),
#  Document(metadata={'source': 'data.txt'}, page_content='15. RESEARCH METHODOLOGY\n16. Identify the indoor-air-quality and ventilation problem.\n17. Review particulate and gaseous pollutant removal technologies.'),
#  Document(metadata={'source': 'data.txt'}, page_content='18. Study fabric filtration, electrostatic filtration and activated-carbon adsorption.\n19. Select materials and components.\n20. Develop the window-panel mechanical design.'),
#  Document(metadata={'source': 'data.txt'}, page_content='21. Develop the airflow path.\n22. Integrate filtration layers.\n23. Integrate fan and sensors.\n24. Develop Blue Pill-based monitoring/control.'),
#  Document(metadata={'source': 'data.txt'}, page_content='25. Develop the electrostatic system with insulation, grounding and safety.\n26. Fabricate the prototype.\n27. Conduct controlled performance testing.'),
#  Document(metadata={'source': 'data.txt'}, page_content='28. Compare air quality before and after filtration.\n29. Evaluate airflow, pressure drop, energy use and electrical behavior.\n30. Identify limitations and optimize the design.'),
#  Document(metadata={'source': 'data.txt'}, page_content='16. CONSTRUCTION PHASE\nThe construction concept involved:\n1. Fabricating a rigid window-compatible frame.\n2. Preparing filtration layers.\n3. Mounting the preliminary fabric filter.'),
#  Document(metadata={'source': 'data.txt'}, page_content='4. Installing the electrostatic stage.\n5. Installing the activated-carbon/final filter.\n6. Providing the fan and airflow path.\n7. Installing sensors.\n8. Installing the Blue Pill controller.'),
#  Document(metadata={'source': 'data.txt'}, page_content='9. Installing pressure and current monitoring.\n10. Providing suitable power supplies.\n11. Enclosing and insulating the electrostatic subsystem.\n12. Testing airflow and electrical operation.'),
#  Document(metadata={'source': 'data.txt'}, page_content='13. Providing access for filter maintenance and replacement.'),
#  Document(metadata={'source': 'data.txt'}, page_content='17. TESTING PARAMETERS\nAir quality:\n- PM10 before and after filtration.\n- PM2.5 before and after filtration.\n- Indicative MQ135 response.\n- Odor/gaseous pollutant response where measurable.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Airflow:\n- Airflow rate.\n- Fan performance.\n- Clean-air delivery.\n\nPressure:\n- Pressure drop across filters.\n- Pressure change with filter loading.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Electrical:\n- Electrostatic current.\n- Voltage behavior where safely measurable.\n- Fan electrical consumption.\n- Overall energy consumption.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Operational:\n- Noise.\n- Filter loading.\n- Maintenance requirements.\n- Stability of operation.'),
#  Document(metadata={'source': 'data.txt'}, page_content='18. PERFORMANCE EVALUATION\nA useful experimental comparison is:\nBefore filtration: measure incoming/outdoor air.\nDuring filtration: operate the panel at a defined fan setting.'),
#  Document(metadata={'source': 'data.txt'}, page_content='After filtration: measure treated air.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Compare PM2.5 reduction, PM10 reduction, sensor response, pressure drop, airflow and power consumption.\n\nRemoval efficiency:\nRemoval efficiency (%) = [(C_in - C_out) / C_in] x 100'),
#  Document(metadata={'source': 'data.txt'}, page_content='C_in = concentration before filtration.\nC_out = concentration after filtration.\n\nUse this only when the measurement setup and sensor accuracy are appropriate.'),
#  Document(metadata={'source': 'data.txt'}, page_content='19. EXPECTED PROJECT CONTRIBUTIONS\nThe project combines:\n- Building ventilation.\n- Indoor environmental quality.\n- Mechanical filtration.\n- Electrostatic particle separation.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Activated-carbon adsorption.\n- Air-quality sensing.\n- Microcontroller-based monitoring.\n- Pressure monitoring.\n- Electrical monitoring.\n- Compact window integration.'),
#  Document(metadata={'source': 'data.txt'}, page_content='The main contribution is exploration of a window-mounted air-cleaning system that treats incoming ventilation air while occupying a compact panel rather than requiring a separate standalone purifier.'),
#  Document(metadata={'source': 'data.txt'}, page_content='20. STRENGTHS\n- Compact and space-efficient.\n- Directly integrated into a window.\n- Multi-stage filtration.\n- Targets different pollutant categories.\n- Potential real-time monitoring.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Replaceable filtration components.\n- Potentially affordable.\n- Energy-conscious design potential.\n- Combines civil/building engineering with electronics and environmental engineering.'),
#  Document(metadata={'source': 'data.txt'}, page_content='21. LIMITATIONS\n- Electrostatic filtration introduces high-voltage safety requirements.\n- Filter pressure drop can reduce airflow.\n- Higher fan power may be required as resistance increases.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- MQ135 is not a highly specific quantitative pollutant analyzer without calibration.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Activated carbon performance depends on carbon properties, pollutant concentration, contact time and saturation.\n- Compact window panels have limited filter area.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Window integration requires proper sealing and structural support.\n- Outdoor weather exposure may affect materials.\n- Maintenance and filter replacement must be considered.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Prototype measurements require controlled testing.\n- Quantitative performance claims should be based on validated measurements.'),
#  Document(metadata={'source': 'data.txt'}, page_content='22. DESIGN CHALLENGES\n23. Achieving sufficient filtration without excessive pressure drop.\n24. Generating effective electrostatic particle capture safely.'),
#  Document(metadata={'source': 'data.txt'}, page_content='25. Preventing electrical shock and sparking.\n26. Keeping the panel compact.\n27. Maintaining sufficient airflow.\n28. Managing fan power consumption.\n29. Providing adequate sensor accuracy.'),
#  Document(metadata={'source': 'data.txt'}, page_content='30. Making filters easy to replace.\n31. Maintaining structural stability.\n32. Integrating electronics without obstructing airflow.\n33. Controlling noise.'),
#  Document(metadata={'source': 'data.txt'}, page_content='34. Protecting the system from environmental exposure.'),
#  Document(metadata={'source': 'data.txt'}, page_content='23. DESIGN DECISIONS RECORDED\n- Window-integrated air-cleaning panel rather than conventional standalone purifier.\n- Three-stage filtration became the main arrangement.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Cotton/fabric filtration for preliminary stage.\n- Electrostatic filtration for fine-particle stage.\n- Activated carbon/carbon fiber for final stage.\n- External fan for forced airflow.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- MQ135 for air-quality monitoring.\n- Blue Pill as microcontroller.\n- Pressure sensing and current sensing included.\n- High-voltage step-up system considered.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Rubber-bush insulation/separation concept considered.\n- Separate insulating spacer later removed from proposed design.\n- Electrical insulation and grounding retained as mandatory.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Wooden/aluminium frame concept.\n- Exploded engineering drawing with dimensions identified as a design output.'),
#  Document(metadata={'source': 'data.txt'}, page_content='24. RESEARCH THRUST AREAS\n- Window-integrated air purification.\n- Hybrid mechanical-electrostatic filtration.\n- PM2.5 removal through compact electrostatic systems.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Activated-carbon adsorption in ventilation systems.\n- Indoor air-quality improvement through filtered ventilation.\n- Pressure-drop optimization in compact filters.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Energy-efficient air-cleaning ventilation.\n- Sensor-based monitoring of window-integrated purification.\n- Building-envelope-integrated air filtration.'),
#  Document(metadata={'source': 'data.txt'}, page_content='25. FUTURE DEVELOPMENT\n- Optimize filter area.\n- Reduce pressure drop.\n- Improve PM2.5 measurement accuracy.\n- Replace/supplement MQ135 with a dedicated particulate sensor.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Improve electrostatic-field uniformity.\n- Improve high-voltage safety.\n- Reduce fan power consumption.\n- Reduce noise.\n- Develop replaceable filter cartridges.\n- Add automatic fan-speed control.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Add filter-life monitoring.\n- Improve weather resistance.\n- Improve window sealing.\n- Develop a more compact enclosure.\n- Conduct long-duration field testing.'),
#  Document(metadata={'source': 'data.txt'}, page_content='26. FINAL SYSTEM ARCHITECTURE\nWindow opening\n  -> Preliminary fabric filter\n  -> Electrostatic fine-particle stage\n  -> Activated carbon/final filter\n  -> Fan/forced airflow'),
#  Document(metadata={'source': 'data.txt'}, page_content='-> Cleaner air to indoor space'),
#  Document(metadata={'source': 'data.txt'}, page_content='Monitoring and control:\nMQ135 + pressure transducer + current transducer\n  -> Blue Pill microcontroller\n  -> monitoring/control functions'),
#  Document(metadata={'source': 'data.txt'}, page_content='27. THESIS/REPORT SECTIONS DISCUSSED\n- Abstract.\n- Introduction.\n- Problem statement.\n- Objectives.\n- Thesis contributions.\n- Literature review.\n- Research methodology.\n- Materials used.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Materials used.\n- Sensors and electronics.\n- Construction phase.\n- Discussion.\n- Summary/conclusion.\n- References.'),
#  Document(metadata={'source': 'data.txt'}, page_content='28. MATERIALS SECTION DISCUSSED\n- Wooden frame.\n- Aluminium structural elements.\n- Cotton fabric filter.\n- Electrostatic mesh/electrode materials.\n- Activated carbon.\n- Carbon fiber.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Carbon fiber.\n- Rubber insulating components.\n- Fan.\n- Sensors.\n- Microcontroller.\n- Power supply.\n- High-voltage components.\n- Wiring and grounding components.'),
#  Document(metadata={'source': 'data.txt'}, page_content='29. IMPORTANT ENGINEERING NOTE'),
#  Document(metadata={'source': 'data.txt'}, page_content='The project description represents concepts discussed during project development. It does not establish that every component, dimension or performance value has been experimentally validated.'),
#  Document(metadata={'source': 'data.txt'}, page_content='For the final thesis, clearly distinguish between:\n- Proposed design.\n- Fabricated prototype.\n- Experimental observations.\n- Measured results.\n- Literature-supported findings.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Future recommendations.'),
#  Document(metadata={'source': 'data.txt'}, page_content='30. OVERALL CONCLUSION\nThe Air Cleaning Window Panel is a compact building-integrated air-cleaning concept combining ventilation and filtration in a single window-mounted system.'),
#  Document(metadata={'source': 'data.txt'}, page_content='Its core design uses:\n- Preliminary fabric filtration for larger particles.\n- Electrostatic filtration for fine particulate matter.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Activated-carbon/carbon-based final filtration for odors and selected gaseous pollutants.\n- A fan for forced airflow.\n- MQ135, pressure and current sensing.\n- Blue Pill microcontroller.'),
#  Document(metadata={'source': 'data.txt'}, page_content='- Wooden/aluminium frame.\n- A dedicated safety approach for the electrostatic subsystem.'),
#  Document(metadata={'source': 'data.txt'}, page_content='The project has potential as a practical civil/environmental engineering prototype because it addresses indoor air quality while integrating directly with a building opening. The most important areas'),
#  Document(metadata={'source': 'data.txt'}, page_content='important areas requiring rigorous validation are particulate-removal efficiency, airflow, pressure drop, energy consumption, electrostatic safety, sensor accuracy and long-term filter performance.'),
#  Document(metadata={'source': 'data.txt'}, page_content='END OF CONSOLIDATED PROJECT INFORMATION')]

# %%
texts = [doc.page_content for doc in finalDocument]

# %%
from langchain_huggingface import HuggingFaceEmbeddings
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2")
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
print(embeddings)
# Out:
# model_name='sentence-transformers/all-MiniLM-L6-v2' cache_folder=None model_kwargs={} encode_kwargs={} query_encode_kwargs={} multi_process=False show_progress=False

# %%
import sys
# !{sys.executable} -m pip install faiss-cpu
from langchain_community.vectorstores import FAISS
db = FAISS.from_documents(finalDocument, embeddings)
db
# Out:
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.12/dist-packages (1.15.0)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (26.2)

# %%
pip install faiss-cpu
# Out:
# Requirement already satisfied: faiss-cpu in /usr/local/lib/python3.12/dist-packages (1.15.0)
# Requirement already satisfied: numpy>=1.25 in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from faiss-cpu) (26.2)

# %%
query = input("Enter your Question: ")
docs = db.similarity_search(query)
for i in range(len(docs)):
  print(docs[i].page_content)
# Out:
# Enter your Question: what is fabric filter
# Layer 3: Final fabric filter containing activated carbon/carbon fiber for residual particles, odors and selected gaseous pollutants.
# The final layer was conceptualized as a fabric/carbon-containing filter providing additional particle filtration and adsorption.
# 5.1 PRELIMINARY FABRIC FILTER
# A cotton/fabric filter was selected as the preliminary stage.
# Purpose:
# - Capture larger suspended particles.
# - Reduce particulate load reaching finer filtration stages.
# 14.3 FABRIC FILTRATION
# Topics included particle capture, filter cake formation, pressure drop, filtration efficiency and filter loading.
